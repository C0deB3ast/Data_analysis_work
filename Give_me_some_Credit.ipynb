# %% [markdown]
# <a href="https://colab.research.google.com/github/C0deB3ast/Data_analysis_work/blob/main/Give_me_some_Credit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Give me some credit/cs-training.csv', na_values=['NA'])

# %%
df.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            150000 non-null  int64
#  1   SeriousDlqin2yrs                      150000 non-null  int64
#  2   RevolvingUtilizationOfUnsecuredLines  150000 non-null  float64
#  3   age                                   150000 non-null  int64
#  4   NumberOfTime30-59DaysPastDueNotWorse  150000 non-null  int64
#  5   DebtRatio                             150000 non-null  float64
#  6   MonthlyIncome                         120269 non-null  float64
#  7   NumberOfOpenCreditLinesAndLoans       150000 non-null  int64
#  8   NumberOfTimes90DaysLate               150000 non-null  int64
#  9   NumberRealEstateLoansOrLines          150000 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
df
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1                 1                              0.766127
# 1                2                 0                              0.957151
# 2                3                 0                              0.658180
# 3                4                 0                              0.233810
# 4                5                 0                              0.907239
# ...            ...               ...                                   ...
# 149995      149996                 0                              0.040674
# 149996      149997                 0                              0.299745
# 149997      149998                 0                              0.246044
# 149998      149999                 0                              0.000000
# 149999      150000                 0                              0.850283
#
# ...

# %%
df = df.rename(columns={'Unnamed: 0' : 'Customer_Id'})

# %%
median_income = df['MonthlyIncome'].median()
df['MonthlyIncome'] = df['MonthlyIncome'].fillna(median_income)

# %%
mode_dependents = df['NumberOfDependents'].mode()[0]
df['NumberOfDependents'] = df['NumberOfDependents'].fillna(mode_dependents)

# %%
df.isna().sum()
# Out:
# Customer_Id                             0
# SeriousDlqin2yrs                        0
# RevolvingUtilizationOfUnsecuredLines    0
# age                                     0
# NumberOfTime30-59DaysPastDueNotWorse    0
# DebtRatio                               0
# MonthlyIncome                           0
# NumberOfOpenCreditLinesAndLoans         0
# NumberOfTimes90DaysLate                 0
# NumberRealEstateLoansOrLines            0
# NumberOfTime60-89DaysPastDueNotWorse    0
# NumberOfDependents                      0
# dtype: int64

# %%
median_age = df['age'].median()
df.loc[df['age'] == 0, 'age'] = median_age

# %%
df[df['NumberOfTimes90DaysLate'] >= 96]
# Out:
#         Customer_Id  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 1733           1734                 1                                   1.0
# 2286           2287                 0                                   1.0
# 3884           3885                 0                                   1.0
# 4417           4418                 0                                   1.0
# 4705           4706                 0                                   1.0
# ...             ...               ...                                   ...
# 147774       147775                 1                                   1.0
# 149153       149154                 1                                   1.0
# 149239       149240                 0                                   1.0
# 149439       149440                 1                                   1.0
# 149769       149770                 0                                   1.0
#
# ...

# %%
df[(df['NumberOfTime30-59DaysPastDueNotWorse'] >= 96) &
   (df['NumberOfTimes90DaysLate'] >= 96) &
   (df['NumberOfTime60-89DaysPastDueNotWorse'] >= 96)].shape
# Out:
# (269, 12)

# %%
df = df[~((df['NumberOfTime30-59DaysPastDueNotWorse'] >= 96) &
   (df['NumberOfTimes90DaysLate'] >= 96) &
   (df['NumberOfTime60-89DaysPastDueNotWorse'] >= 96))]

# %%
df.shape
# Out:
# (149731, 12)

# %%
df[df['RevolvingUtilizationOfUnsecuredLines']>1].shape
# Out:
# (3321, 12)

# %%
df['RevolvingUtilizationOfUnsecuredLines'].sort_values(ascending=False).head(20)
# Out:
# 85489     50708.0
# 31414     29110.0
# 16956     22198.0
# 149160    22000.0
# 149279    20514.0
# 117315    18300.0
# 21978     17441.0
# 124533    13930.0
# 72592     13498.0
# 71705     13400.0
# 125718    12369.0
# 58852     11843.0
# 83052     11553.0
# 76726     10821.0
# 13669     10209.0
# 123071    10151.0
# 50695      9684.0
# 8199       9340.0
# 60021      9193.0
# 99651      8831.0
# Name: RevolvingUtilizationOfUnsecuredLines, dtype: float64

# %%
cap_val= df['RevolvingUtilizationOfUnsecuredLines'].quantile(0.99)
df['RevolvingUtilizationOfUnsecuredLines'] = df['RevolvingUtilizationOfUnsecuredLines'].clip(upper=cap_val)

# %%
df['RevolvingUtilizationOfUnsecuredLines'].describe()
# Out:
# count    149731.000000
# mean          0.319279
# std           0.351296
# min           0.000000
# 25%           0.029771
# 50%           0.153491
# 75%           0.555601
# max           1.093342
# Name: RevolvingUtilizationOfUnsecuredLines, dtype: float64

# %%
df = df[df['MonthlyIncome'] >= 100]

# %%
#df[df['DebtRatio'] > 10][['DebtRatio', 'MonthlyIncome']].head(20)

# %%
df[df['MonthlyIncome'] < 100 ]['DebtRatio'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: DebtRatio, dtype: float64

# %%
df.shape
df['DebtRatio'].describe()
# Out:
# count    147463.000000
# mean        337.685386
# std        2022.217896
# min           0.000000
# 25%           0.173587
# 50%           0.361409
# 75%           0.801805
# max      329664.000000
# Name: DebtRatio, dtype: float64

# %%
df[df['DebtRatio'] == df['DebtRatio'].max()][['DebtRatio', 'MonthlyIncome', 'age']]
# Out:
#        DebtRatio  MonthlyIncome  age
# 60152   329664.0         5400.0   65

# %%
Q1 = df['DebtRatio'].quantile(0.25)
Q3 = df['DebtRatio'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR

print("Upper bound:", upper_bound)
print("Rows above bound:", (df['DebtRatio'] > upper_bound).sum())
# Out:
# Upper bound: 1.744133106
# Rows above bound: 29389

# %%
print("Rows with DebtRatio > 50:", (df['DebtRatio'] > 50).sum())
print("Percentage:", (df['DebtRatio'] > 50).sum() / len(df) * 100)
# Out:
# Rows with DebtRatio > 50: 24135
# Percentage: 16.366817438950786

# %%
df['implied_debt_payment'] = df['DebtRatio'] * df['MonthlyIncome']
df['implied_debt_payment'].describe()
# Out:
# count    1.474630e+05
# mean     1.823544e+06
# std      1.091997e+07
# min      0.000000e+00
# 25%      8.297839e+02
# 50%      2.154676e+03
# 75%      4.918550e+03
# max      1.780186e+09
# Name: implied_debt_payment, dtype: float64
